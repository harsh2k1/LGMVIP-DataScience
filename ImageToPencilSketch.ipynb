# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh2k1/LGMVIP-DataScience/blob/main/ImageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task-3: Image to Pencil Sketch with Python
# # Level: Beginner
# # Name: Harshpreet Singh
# # LGMVIP OCTOBER-2021

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
path = '/content/drive/My Drive/elonmusk.jpg'
img = cv2.imread(path)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=968x652 at 0x7F594F23A390>

# %% [markdown]
# # Converting to grey image

# %%
grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=968x652 at 0x7F5945FAD850>

# %% [markdown]
# # Invert image

# %%
invert_img = cv2.bitwise_not(grey_img)
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=968x652 at 0x7F5945FBAD10>

# %% [markdown]
# # Blur image

# %%
k_size = 7
blur_img = cv2.GaussianBlur(invert_img, (k_size,k_size),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=968x652 at 0x7F5945FC2950>

# %% [markdown]
# # Invert Blurred Image

# %%
invblur_img = cv2.bitwise_not(blur_img)
cv2_imshow(invblur_img)
# Out:
# <PIL.Image.Image image mode=L size=968x652 at 0x7F5945FC2F50>

# %% [markdown]
# # Sketch image

# %%
sketch_img = cv2.divide(grey_img,invblur_img, scale=256.0)
cv2_imshow(sketch_img)
# Out:
# <PIL.Image.Image image mode=L size=968x652 at 0x7F594474B8D0>
